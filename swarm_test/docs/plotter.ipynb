# %%
import pandas as pd  
import numpy as np
import seaborn as sns  
import matplotlib.pyplot as plt  
from scipy.interpolate import interp1d  

df = pd.read_excel("../data/datas.xlsx")

if __name__=="__main__":
    # print(df.head())
    # 假设你的列名是 "06time" 和 "06num"，并且你想要平滑 "06num"  
    x = df['06time'].values  
    y = df['06num'].values  

    # 计算y的差值
    y_diff = np.diff(y)
    # y_diff = np.insert(y_diff, 0,0)   
    x_mid = (x[:-1] + x[1:]) / 2  # 计算x的中点位置  

    # 插值和平滑处理  
    x_new = np.linspace(x.min(), x.max(), num=100)  # 创建一个新的x轴，包含更多点  
    f = interp1d(x, y, kind='cubic')  # 使用三次样条插值  
    y_new = f(x_new)  # 计算新的y值  
    
    # 使用matplotlib绘制平滑曲线  
    sns.set_theme()
    plt.figure(figsize=(7, 4.2))  
    plt.plot(x_new, y_new, label='Smoothed line')  

    for i in range(len(y_diff)):  
        plt.bar(x[i]-0.25, y_diff[i], width=(x[i+1] - x[i]) / 2 , bottom=y[i], align='edge', color='C1') 

    # 添加原始数据点（可选）  
    plt.scatter(x, y, c='gray', label='Original data')  
    
    # 添加标题和轴标签  
    plt.title('06numbers-times figure')  
    plt.xlabel('Time')  
    plt.ylabel('Num')  
    plt.legend()  # 显示图例  
    
    # 显示图形  
    plt.show()

# %%
import pandas as pd  
import numpy as np
import seaborn as sns  
import matplotlib.pyplot as plt  
from scipy.interpolate import interp1d  

df = pd.read_excel("../data/datas.xlsx")

if __name__=="__main__":
    print(df.head())
    x = []; y=[]

    for val in df["06time"]:
        x.append(val)

    for val in df["06num"]:
        y.append(val)

    for val in df["07time"]:
        x.append(val)
    print(x)

    for val in df["07num"]:
        y.append(val)
    print(y)
# Out:
#    06time  06num  07time  07num
# 0   623.0    4.0     701     31
# 1   624.0   10.0     702     33
# 2   625.0   14.0     703     34
# 3   626.0   15.0     704     35
# 4   627.0   17.0     705     36
# [623.0, 624.0, 625.0, 626.0, 627.0, 628.0, 629.0, 630.0, nan, nan, nan, nan, nan, nan, 701, 702, 703, 704, 705, 706, 707, 708, 709, 710, 711, 712, 713, 714]
# [4.0, 10.0, 14.0, 15.0, 17.0, 21.0, 22.0, 23.0, nan, nan, nan, nan, nan, nan, 31, 33, 34, 35, 36, 38, 39, 43, 44, 45, 46, 47, 48, 49]

# %%
import pandas as pd

x1 = [-0.000776466, 0.126632, 0.255983, 0.385513, 0.515027, 0.644505, 0.773941, 0.90333, 1.03267, 1.16194, 1.29115, 1.42029, 1.54934, 1.6783, 1.80715, 1.93587, 2.06445, 2.19287, 2.3211, 2.44912, 2.57688, 2.70435, 2.83148, 2.95822, 3.08449, 3.21022, 3.33539, 3.46023, 3.5863, 3.71491, 3.84477, 3.97458, 4.10356, 4.23224, 4.36084, 4.48943, 4.618, 4.74658, 4.87515, 5.00373, 5.1323, 5.26087, 5.38944, 5.51801, 5.64657, 5.77514, 5.9037, 6.03225, 6.16081, 6.28935, 6.41789, 6.54642, 6.67494, 6.80344, 6.93194, 7.06043, 7.18894, 7.31746, 7.44605, 7.57472, 7.70353, 7.79903, 7.86404, 7.90824, 7.93824, 7.95856, 7.9723, 7.98155, 7.98778, 7.99195, 7.99473, 7.99658, 7.99781, 7.99861, 7.99914, 7.99947, 7.99969, 7.99983, 7.99991, 7.99995, 7.99998]
y4 = [-0.000250688, 0.0260777, 0.0490065, 0.0723746, 0.0965181, 0.121515, 0.147426, 0.174311, 0.202237, 0.231275, 0.261503, 0.293003, 0.325867, 0.360191, 0.396081, 0.433664, 0.473162, 0.515481, 0.56643, 0.629064, 0.68283, 0.724512, 0.753692, 0.770079, 0.773509, 0.77264, 0.773891, 0.787655, 0.788445, 0.776252, 0.755576, 0.733106, 0.71024, 0.687282, 0.664299, 0.641308, 0.618312, 0.595312, 0.572307, 0.549297, 0.526281, 0.503257, 0.480224, 0.457181, 0.434124, 0.41105, 0.387957, 0.364837, 0.341684, 0.318489, 0.295241, 0.271928, 0.248537, 0.225063, 0.201509, 0.177898, 0.15429, 0.130793, 0.107581, 0.084911, 0.0631277, 0.0437185, 0.0316782, 0.0243762, 0.0200242, 0.0174656, 0.0159777, 0.0151201, 0.0146295, 0.0143508, 0.0141934, 0.014105, 0.0140556, 0.0140282, 0.014013, 0.0140047, 0.0140001, 0.0139977, 0.0139964, 0.0139957, 0.0139954]

x0 = [(80-1.5*i)/10 for i in range(81)]
y0 = [-0.5 for i in range(81)]

df = pd.DataFrame({"x-OBS":x0, "y-OBS":y0,
                   "x-DC":x1, "y-DC":y1, 
                   "x-DCBF":x2, "y-DCBF":y2,
                   "x-ACBF-.00":x3, "y-ACBF-.00":y3,
                   "x-ACBF-.30":x4, "y-ACBF-.30":y4})
df.to_excel("../data/data1.xlsx", index=False)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.patches as patches

df = pd.read_excel("./data0729/data_use.xlsx", sheet_name=0)
df_head = df.head(55)


plotsize = (9, 5)
# sns.set_theme(style='whitegrid', rc={'font.family': 'serif', 'font.serif': ['Times New Roman'], "axes.labelsize": 15}) # style='whitegrid'
# sns.set_theme(style='whitegrid', rc={'font.family': 'serif', "axes.labelsize": 15})
sns.set_theme(style='whitegrid')

# 获取颜色列表
palettes = sns.color_palette()
# print(palettes)


fig, axs = plt.subplots(figsize=plotsize)
axs.set_xlabel("x(m)")
axs.set_ylabel("y(m)")
axs.set_xlim(0, 8)
axs.set_ylim(-2.2)

# 使用tick_params设置坐标轴刻度标签的字体大小
axs.tick_params(axis='both', labelsize=15)  # 'both'代表x轴和y轴

# sns.lineplot(data=df_head, x=df_head.columns[0], y=df_head.columns[1], 
#              alpha=0.9, color="black", linewidth=3, linestyle="--", label="Obstacle trajectory")

sns.lineplot(data=df, x=df.columns[2], y=df.columns[3], 
             alpha=0.9, color=palettes[0], linewidth=4, label="Dynamic Euclidean distance constraint (cite)")

sns.lineplot(data=df, x=df.columns[4], y=df.columns[5], 
             alpha=0.9, color=palettes[1], linewidth=4, label="Dynamic control barrier function constraint (cite)")

sns.lineplot(data=df, x=df.columns[6], y=df.columns[7], 
             alpha=0.9, color=palettes[2], linewidth=4, label="Proposed approach (tau_scale=0.00)")

sns.lineplot(data=df, x=df.columns[8], y=df.columns[9], 
             alpha=0.9, color=palettes[3], linewidth=4, label="Proposed approach (tau_scale=0.35)")


t_index = 23
xt = []
yt = []
color_t = [(.0, .0, .0)]
for i in range(5):
    xt.append(df[df.columns[i*2]][t_index])
    yt.append(df[df.columns[i*2+1]][t_index])
    if i>0:
        color_t.append(palettes[i-1])

plt.scatter(xt, yt, c=color_t, s=30, alpha=1)


# 创建一个圆形补丁，指定中心和半径
circle = patches.Circle((df[df.columns[0]][t_index], df[df.columns[1]][t_index]), alpha=1.0 ,radius=1.0, edgecolor='none', facecolor='dimgray')
axs.add_patch(circle)

# 关闭网格线
axs.grid(False)

# 创建图例
legend = plt.legend()

# 设置图例的字体大小
for text in legend.get_texts():
    text.set_fontsize(15)  # 设置字体大小为12

# 隐藏图例
legend.set_visible(False)


plt.show()

# %%
import pandas as pd  
import numpy as np

## 2024-12-26 实验数据处理

# MPC-DC
list1_x = [-0.00165712, 0.125752, 0.255102, 0.38461, 0.514099, 0.64355, 0.772959, 0.90232, 1.03163, 1.16088, 1.29006, 1.41916, 1.54818, 1.67711, 1.80592, 1.93462, 2.06317, 2.19157, 2.31978, 2.44778, 2.57554, 2.70302, 2.83018, 2.95696, 3.0833, 3.20914, 3.33445, 3.45944, 3.58553, 3.71415, 3.84401, 3.97382, 4.10279, 4.23147, 4.36006, 4.48864, 4.61721, 4.74578, 4.87435, 5.00292, 5.13148, 5.26005, 5.38861, 5.51718, 5.64574, 5.7743, 5.90285, 6.0314, 6.15995, 6.28849, 6.41702, 6.54554, 6.67406, 6.80256, 6.93105, 7.05954, 7.18803, 7.31655, 7.44513, 7.5738, 7.7026, 7.7984, 7.86362, 7.90796, 7.93805, 7.95844, 7.97221, 7.9815, 7.98774, 7.99193, 7.99472, 7.99658, 7.9978, 7.99861, 7.99913, 7.99947, 7.99969, 7.99983, 7.99991, 7.99995, 7.99998]
list1_y = [0.000343255, 0.0261703, 0.0391486, 0.0504501, 0.0619669, 0.0738949, 0.0862796, 0.0991546, 0.112556, 0.126521, 0.141092, 0.156315, 0.17224, 0.188921, 0.206419, 0.224799, 0.244133, 0.264502, 0.285992, 0.308699, 0.33273, 0.358202, 0.385244, 0.413996, 0.44461, 0.477223, 0.511831, 0.547594, 0.579234, 0.598128, 0.604087, 0.597051, 0.580716, 0.562206, 0.543163, 0.523983, 0.504764, 0.485532, 0.466292, 0.447047, 0.427796, 0.408537, 0.389269, 0.369992, 0.350701, 0.331394, 0.312067, 0.292714, 0.273328, 0.253901, 0.234422, 0.21488, 0.195267, 0.175581, 0.155835, 0.136065, 0.116344, 0.0967965, 0.0776106, 0.0590487, 0.0414516, 0.0294099, 0.0220448, 0.017623, 0.0150059, 0.013474, 0.0125851, 0.012073, 0.0117797, 0.0116126, 0.0115178, 0.0114642, 0.011434, 0.0114171, 0.0114076, 0.0114023, 0.0113993, 0.0113977, 0.0113968, 0.0113963, 0.0113961]

# MPC-ECBF-0.4
list8_x = [-0.00169872, 0.12571, 0.25506, 0.38506, 0.514411, 0.64182, 0.766013, 0.885751, 0.999837, 1.10713, 1.20656, 1.29713, 1.37794, 1.44818, 1.39276, 1.34565, 1.31088, 1.28878, 1.27959, 1.28338, 1.30013, 1.32967, 1.3717, 1.42579, 1.49142, 1.56793, 1.65455, 1.75041, 1.85456, 1.96595, 2.08348, 2.20597, 2.33219, 2.46089, 2.59078, 2.72056, 2.84893, 2.9754, 3.10149, 3.22751, 3.35352, 3.47952, 3.60552, 3.73152, 3.85752, 3.98351, 4.1095, 4.23549, 4.36147, 4.48745, 4.61342, 4.73939, 4.86535, 4.9913, 5.11725, 5.24318, 5.36909, 5.495, 5.62088, 5.74674, 5.87258, 5.99839, 6.12418, 6.24996, 6.37579, 6.50175, 6.62803, 6.75493, 6.88288, 7.01214, 7.14214, 7.27157, 7.39914, 7.52357, 7.64363, 7.70307, 7.71941, 7.71191, 7.6943, 7.67628, 7.66456]
list8_y = [0.000310394, 0.0261374, 0.0391158, 0.0391158, 0.0261374, 0.000310393, -0.0381072, -0.0887316, -0.151057, -0.22446, -0.308209, -0.401465, -0.503298, -0.612689, -0.503797, -0.382632, -0.25737, -0.129261, 0.000413093, 0.130358, 0.259274, 0.385874, 0.508893, 0.627102, 0.739319, 0.844424, 0.941365, 1.02918, 1.10698, 1.17399, 1.22955, 1.2731, 1.3042, 1.32255, 1.32795, 1.32036, 1.29986, 1.26976, 1.23811, 1.2062, 1.17423, 1.14224, 1.11025, 1.07824, 1.04623, 1.0142, 0.982167, 0.950116, 0.91805, 0.885965, 0.85386, 0.821731, 0.789575, 0.757387, 0.725161, 0.692892, 0.660571, 0.628189, 0.595734, 0.563193, 0.530557, 0.49782, 0.464999, 0.432161, 0.399476, 0.367321, 0.336447, 0.308256, 0.285214, 0.271414, 0.270589, 0.282745, 0.307763, 0.345391, 0.395254, 0.427239, 0.438264, 0.432026, 0.41412, 0.391715, 0.373718]

data = {
    'DC_x':     list1_x,
    'DC_y':     list1_y,
    'CBF_x':    list2_x,
    'CBF_y':    list2_y,
    'DCBF_x':   list3_x,
    'DCBF_y':   list3_y,
    'ECBF_x00': list4_x,
    'ECBF_y00': list4_y,
    'ECBF_x10': list5_x,
    'ECBF_y10': list5_y,
    'ECBF_x20': list6_x,
    'ECBF_y20': list6_y,
    'ECBF_x35': list7_x,
    'ECBF_y35': list7_y,
    'ECBF_x40': list8_x,
    'ECBF_y40': list8_y,
}

df = pd.DataFrame(data)
# print(df)
df.to_excel("./data1226/output.xlsx", index=False)
